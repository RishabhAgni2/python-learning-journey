# %%
##Basic syntax Rules in Python
## it is case sensitive language
name = "Rishabh"
Name = "Agnihotri"

print(name)
print(Name)
# Out:
# Rishabh
# Agnihotri

# %%
##indentation to define blocks of code.
##Consistent use of spaces commonly 4 spaces per indentation level is recommended.
x = 5
if x > 3:
    print("x is greater than 3")
# Out:
# x is greater than 3

# %%
##line continuation using the backlash character(\)

total = 1 +2+4+\
    3+45
print(total)
# Out:
# 55

# %%
##multiple statements on a single line 
x=5; y=19; z= x+y
print(z)
# Out:
# 24

# %%
##varirable assignment in python
age=32##age is integer
name="Rishabh" ##name is string

type(age)
##type(name)
# Out:
# int

# %%
##code example for te indentation
if True:
    print("correct indentation")
    if False:
        print("this not printed")
    print("this will printed")
print("this is outside the if block")
# Out:
# correct indentation
# this will printed
# this is outside the if block
